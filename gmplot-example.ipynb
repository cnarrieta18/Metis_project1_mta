# %%
# import gmplot package 
import gmplot 
import math
  
gmap = gmplot.GoogleMapPlotter

#API key for Google Cloud that David set up
gmap.apikey = '...'

#This will draw a triangle centered at latitude, longitude. Here 'value' is the value that is being displayed
#via the size of the triangle. 'factor' is an overall sizing factor that will be the same for a series of
#triangles.
def draw_triangle (latitude, longitude, value, factor):
    latitude_list = []
    longitude_list = []
    latitude_list.append (latitude + (.01*(value/factor)))
    longitude_list.append (longitude)
    latitude_list.append (latitude - (.005*(value/factor)))
    longitude_list.append (longitude - (0.008660254037844387*(value/factor))/math.cos(latitude/57.29577951308232))
    latitude_list.append (latitude - (.005*(value/factor)))
    longitude_list.append (longitude + (0.008660254037844387*(value/factor))/math.cos(latitude/57.29577951308232))
    #Draw the triangle
    #gmap1.scatter( latitude_list, longitude_list, '# FF0000', 
    #                            size = 40, marker = False) 
    
    # polygon method Draw a polygon with 
    # the help of coordinates 
    gmap1.polygon(latitude_list, longitude_list, 
                   color = 'blue') 




# GoogleMapPlotter return Map object 
# Pass the center latitude and 
# center longitude (GCT location)
gmap1 = gmplot.GoogleMapPlotter(40.74329, 
                                -73.987985, 14 ) 
gmap1.apikey = 'AIzaSyAKKch50xUpIXVn0jPjYQW5bbtKGaXFcMw'

#latitude and longitude of a triangle around GCT
latitude_list = [ 40.75, 40.75, 40.755 ] 
longitude_list = [ -73.9722, -73.9822, -73.9772 ] 
  
#Draw the triangle
#gmap1.scatter( latitude_list, longitude_list, '# FF0000', 
#                                size = 40, marker = False) 
  
# polygon method Draw a polygon with 
# the help of coordinates 
#gmap1.polygon(latitude_list, longitude_list, 
#                   color = 'cornflowerblue') 

scaling_factor = 1000000

draw_triangle (40.7527, -73.9772, 169169, scaling_factor)
draw_triangle (40.7506, -73.9935, 161227, scaling_factor)
draw_triangle (40.7557103105, -73.8248533672, 63624, scaling_factor)
draw_triangle (40.746389, -73.981944, 151829, scaling_factor)
draw_triangle (40.74329, -73.984165, 151829, scaling_factor)
draw_triangle (40.740169, -73.98644, 177950, scaling_factor)
draw_triangle (40.749338, -73.987985, 161227, scaling_factor)
draw_triangle (40.734722, -73.990278, 182531, scaling_factor)
draw_triangle (40.756, -73.987, 126679, scaling_factor)

# Pass the absolute path 
gmap1.draw( "/users/skydivedavis/Documents/sample_map109.html" )
